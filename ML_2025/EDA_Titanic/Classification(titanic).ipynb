# %% [markdown]
# # **Classification using scitlearn **
#
# This noteBook cover the following concepts
#
# ---
#
#
# 1.Visualization of Data
# 2.Preprocessing of Data
# 3.Model Fitting using Scikit Learn
# 4.Model Evaluation
# 5.Result Analysis
#
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn # used for tookil for machine learning
import seaborn as sns # for also used visualizaion(it is advance than matplotlib) easy to use
# Purpose: Imports the warnings module, which is used to handle warnings in Python.
# Warnings are messages that indicate potential issues (but not errors) in the code.
import warnings
# Purpose: Configures Python to ignore all warnings.
# Effect: Any warning (e.g., deprecation warnings, future warnings) will not be displayed in the output.
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] =[10,5]


# Purpose: Specifically ignores FutureWarning messages while allowing other warnings to show.
# Difference from filterwarnings('ignore'):
# filterwarnings('ignore') silences all warnings.
# simplefilter here only ignores FutureWarning (e.g., warnings about future changes in libraries).
warnings.simplefilter(action = 'ignore',category = FutureWarning)

# %%
current_palette1 = sns.color_palette()
sns.palplot(current_palette1)
plt.show()

# %%
# import seaborn as sns

# # Ek palette bana lo
# current_palette2 = sns.color_palette('Reds')

# # Usay plot karo
# sns.palplot(current_palette2)

# %%
import seaborn as sns

# Ek palette bana lo
current_palette2 = sns.color_palette('colorblind')

# Usay plot karo
sns.palplot(current_palette2)

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML_2025/Day2/tested.csv')

# %%
df.shape
# Out:
# (418, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # **Distribution Plot**

# %%
# sns.histplot(df['parch'],kde=False)
# plt.show()
sns.histplot(df['Pclass'], kde=False)
plt.show()

# %% [markdown]
# # **kdeplot(kernal Density Estimation)**

# %%
# Plot KDE for 'age' column
sns.kdeplot(data=df, x='Age', fill=True)

# Add title and labels (optional)
plt.title('Kernel Density Estimate (KDE) of Age')
plt.xlabel('Age')
plt.ylabel('Density')

plt.show()

# %%
sns.displot(df['Age'], kind="kde")
plt.show()

# %%
sns.displot(df['Age'])
plt.show()

# %% [markdown]
# # **Relation Plot**

# %%
# relation plot
sns.relplot(
    x='Age',
    y='Fare',
    col='Pclass',   # corrected from 'pxlass'
    hue='Sex',
    # style='sex',    # use a variable here, not 'line'
    kind='scatter', # optional: default is 'scatter'; use 'line' if it's time series
    data=df
)
plt.show()

# %%
# ScatterPlot
plt.figure(figsize=(8,8))
sns.scatterplot(x='Age',y='Fare',hue='Sex',data=df)
plt.show()

# %%
# line plot
sns.lineplot(x='Age',y='Fare',hue='Sex',style='Sex',data=df)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.stripplot(x='Sex',y='Age',hue='Sex', data=df)
plt.show()

# %% [markdown]
# # **Bar plot**

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='Sex',y='Survived',hue='Pclass',data=df)
plt.show()

# %%
# box plot
# it shows the five number summary
plt.figure(figsize=(8,8))
sns.boxplot(x='Survived',y='Age',data=df)
plt.show()

# %%
# Violin Plot
sns.violinplot(x='Survived',y='Age', hue='Sex',data=df)
plt.show()

# %%
sns.countplot(x='Survived', data=df, palette='Blues');
plt.show()

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML_2025/Day2/tested.csv')
print('data uploaded successfully')
# Out:
# data uploaded successfully

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
# heatmap
sns.heatmap(df.isnull(),yticklabels=False, cbar=False,cmap = 'tab20c_r')
plt.title('Missing Data:Training Set')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4088462978.py in <cell line: 0>()
#       1 # heatmap
# ----> 2 sns.heatmap(df.isnull(),yticklabels=False, cbar=False,cmap = 'tab20c_r')
#       3 plt.title('Missing Data:Training Set')
#       4 plt.show()
#
# NameError: name 'sns' is not defined

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='Pclass',y = 'Age', data=df,palette='GnBu_d').set_title('Age by Passender Class')
plt.show()

# %%
# imputation function
def impute_age(cols):
  age=cols[0]
  pclass = cols[1]
  if pd.isnull(age):
    if pclass == 1:
      return 37
    elif pclass ==2:
      return 29
    else:
      return 24
  else:
    return age

  # apply function
  df['Age']=df[['Age','Pclass']].apply(impute_age,axis=1)

# %%
# Remove cabin feature
df.drop('Cabin',axis=1,inplace=True)

# %%
# Remove rows with missing values
df.dropna(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 409         1301         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 3                                   Wirz, Mr. Albert    male  27.0      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
df.drop('Name',axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            892         0       3    male  34.5      0      0
# 1            893         1       3  female  47.0      1      0
# 2            894         0       2    male  62.0      0      0
# 3            895         0       3    male  27.0      0      0
# 4            896         1       3  female  22.0      1      1
# ..           ...       ...     ...     ...   ...    ...    ...
# 409         1301         1       3  female   3.0      1      1
# 411         1303         1       1  female  37.0      1      0
# 412         1304         1       3  female  28.0      0      0
# 414         1306         1       1  female  39.0      0      0
# 415         1307         0       3    male  38.5      0      0
#
#                  Ticket      Fare Embarked
# 0                330911    7.8292        Q
# 1                363272    7.0000        S
# 2                240276    9.6875        Q
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   331.000000  331.000000  331.000000  331.000000  331.000000
# mean   1100.232628    0.383686    2.141994   30.181269    0.483384
# std     122.910180    0.487019    0.846251   14.104573    0.875004
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     992.500000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.000000    0.000000    2.000000   27.000000    0.000000
# 75%    1210.500000    1.000000    3.000000   39.000000    1.000000
# max    1307.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  331.000000  331.000000
# mean     0.398792   40.982087
# std      0.811582   61.228558
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   16.000000
# 75%      1.000000   40.633350
# max      6.000000  512.329200

# %% [markdown]
# Getting Ready Model

# %%
df.shape
# Out:
# (331, 10)

# %%
# identify categorical data
df.select_dtypes(['category']).columns
# Out:
# Index([], dtype='object')

# %%
df.drop('PassengerId',axis=1,inplace=True)

# %%
df.drop('Ticket',axis=1,inplace=True)

# %%
sex=pd.get_dummies(df['Sex'],drop_first=True) #drop_first prevents multi_collinearity
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  34.5      0      0    7.8292        Q
# 1           1       3  female  47.0      1      0    7.0000        S
# 2           0       2    male  62.0      0      0    9.6875        Q
# 3           0       3    male  27.0      0      0    8.6625        S
# 4           1       3  female  22.0      1      1   12.2875        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 409         1       3  female   3.0      1      1   13.7750        S
# 411         1       1  female  37.0      1      0   90.0000        Q
# 412         1       3  female  28.0      0      0    7.7750        S
# 414         1       1  female  39.0      0      0  108.9000        C
# 415         0       3    male  38.5      0      0    7.2500        S
#
# [331 rows x 8 columns]

# %%
# Assume 'sex' is a Series with True/False values
sex = sex.astype(int)

# Then concatenate
df = pd.concat([df, sex], axis=1)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  male
# 0         0       3    male  34.5      0      0   7.8292        Q     1
# 1         1       3  female  47.0      1      0   7.0000        S     0
# 2         0       2    male  62.0      0      0   9.6875        Q     1
# 3         0       3    male  27.0      0      0   8.6625        S     1
# 4         1       3  female  22.0      1      1  12.2875        S     0

# %%
df.drop('Sex',axis=1,inplace=True)

df
# Out:
#      Survived  Pclass   Age  SibSp  Parch      Fare Embarked  male
# 0           0       3  34.5      0      0    7.8292        Q     1
# 1           1       3  47.0      1      0    7.0000        S     0
# 2           0       2  62.0      0      0    9.6875        Q     1
# 3           0       3  27.0      0      0    8.6625        S     1
# 4           1       3  22.0      1      1   12.2875        S     0
# ..        ...     ...   ...    ...    ...       ...      ...   ...
# 409         1       3   3.0      1      1   13.7750        S     0
# 411         1       1  37.0      1      0   90.0000        Q     0
# 412         1       3  28.0      0      0    7.7750        S     0
# 414         1       1  39.0      0      0  108.9000        C     0
# 415         0       3  38.5      0      0    7.2500        S     1
#
# [331 rows x 8 columns]

# %% [markdown]
# # **Objedtive: Machine Learning**
# Now all the data is numerice
#
#
# Now train data is perfect for machine learning

# %%
# embark ko dell krny se sary result khrab ho gye hay
df.drop('Embarked',axis=1,inplace=True)

# %% [markdown]
# # **Target Variable spliting**
# we will split the full dataset into **Input** and **target** variables

# %%
# create matrix of feature
x = df.drop('Survived',axis=1) # grab everything else but 'sruvived'

# create target variable
y = df['Survived'] # y is the column we are trying to predict

# %%
x.shape
# Out:
# (331, 6)

# %%
y.shape
# Out:
# (331,)

# %%
df
# Out:
#      Survived  Pclass   Age  SibSp  Parch      Fare  male
# 0           0       3  34.5      0      0    7.8292     1
# 1           1       3  47.0      1      0    7.0000     0
# 2           0       2  62.0      0      0    9.6875     1
# 3           0       3  27.0      0      0    8.6625     1
# 4           1       3  22.0      1      1   12.2875     0
# ..        ...     ...   ...    ...    ...       ...   ...
# 409         1       3   3.0      1      1   13.7750     0
# 411         1       1  37.0      1      0   90.0000     0
# 412         1       3  28.0      0      0    7.7750     0
# 414         1       1  39.0      0      0  108.9000     0
# 415         0       3  38.5      0      0    7.2500     1
#
# [331 rows x 7 columns]

# %%
import pandas as pd
from sklearn import preprocessing

# Example: x ke sirf numeric columns nikaalo
x_numeric = x.select_dtypes(include=['int64', 'float64'])

scaler = preprocessing.StandardScaler()
x_transform = scaler.fit_transform(x_numeric)

print(x_transform[:5])   # first 5 rows after scaling
# Out:
# [[ 1.01542612  0.30665727 -0.55327231 -0.49211953 -0.54228095  0.78901776]
#  [ 1.01542612  1.19423645  0.59130978 -0.49211953 -0.55584416 -1.2673986 ]
#  [-0.16804587  2.25933148 -0.55327231 -0.49211953 -0.51188479  0.78901776]
#  [ 1.01542612 -0.22589024 -0.55327231 -0.49211953 -0.52865069  0.78901776]
#  [ 1.01542612 -0.58092192  0.59130978  0.74190748 -0.46935665 -1.2673986 ]]

# %%
x_transform
# Out:
# array([[ 1.01542612,  0.30665727, -0.55327231, -0.49211953, -0.54228095,
#          0.78901776],
#        [ 1.01542612,  1.19423645,  0.59130978, -0.49211953, -0.55584416,
#         -1.2673986 ],
#        [-0.16804587,  2.25933148, -0.55327231, -0.49211953, -0.51188479,
#          0.78901776],
#        ...,
#        [ 1.01542612, -0.15488391, -0.55327231, -0.49211953, -0.5431675 ,
#         -1.2673986 ],
#        [-1.35151786,  0.62618578, -0.55327231, -0.49211953,  1.11093161,
#         -1.2673986 ],
#        [ 1.01542612,  0.59068261, -0.55327231, -0.49211953, -0.55175491,
#          0.78901776]])

# %%
# use x and y variables to split the training data into and test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state=42)

# %% [markdown]
# # **Model Training**

# %% [markdown]
# **1. Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression

print('Logistic Regression')
# create instance of model
log_reg = LogisticRegression()

# pass training data into model
log_reg.fit(x_train,y_train)
# Out:
# Logistic Regression
# LogisticRegression()

# %% [markdown]
# # **Model Evaluation**

# %%
from sklearn.metrics import accuracy_score
# prediction from model
y_pred_log_reg = log_reg.predict(x_test)

print('Logistic Regression')
print('-----'*30)
log_reg_accuracy = round(accuracy_score(y_test,y_pred_log_reg) *100,2)
print('Accuracy: ',log_reg_accuracy,'%')
# Out:
# Logistic Regression
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Accuracy:  100.0 %

# %% [markdown]
# # **2. Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

print('Decision Tree Classifier')
# create instance of model
Dtree = DecisionTreeClassifier()

# pass training data into model
Dtree.fit(x_train,y_train)
# Out:
# Decision Tree Classifier
# DecisionTreeClassifier()

# %% [markdown]
# # **Model Evaluation**

# %%
# from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score
# prediction from model
y_pred_Dtree = Dtree.predict(x_test)

print('Decision Tree Classifier')
print('-----'*30)
Dtree_accuracy = round(accuracy_score(y_test,y_pred_Dtree) *100,2)
print('Accuracy: ',Dtree_accuracy,'%')
# Out:
# Decision Tree Classifier
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Accuracy:  100.0 %

# %% [markdown]
# # **3. Random Forest**

# %% [markdown]
# **Model Training**

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

print('Random Forest Classifier')

# pass training data into modle
rfc.fit(x_train,y_train)
# Out:
# Random Forest Classifier
# RandomForestClassifier()

# %% [markdown]
# # **Model Evaluation**

# %%
from os import access
from sklearn.metrics import accuracy_score

# prediction from the model
y_pred_rfc = rfc.predict(x_test)


print('Random Forest Classifier')
# accuracy
print('----'*30)
rfc_accuracy = round(accuracy_score(y_test,y_pred_rfc) *100,2)
print('Accuracy: ',rfc_accuracy,'%')
# Out:
# Random Forest Classifier
# ------------------------------------------------------------------------------------------------------------------------
# Accuracy:  100.0 %

# %% [markdown]
# # **4. Gradient Bossting Classifier**

# %%
from sklearn.ensemble import GradientBoostingClassifier

# create instance
gbc = GradientBoostingClassifier()

# pass training data into model
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %% [markdown]
# # **Model Evaluation**

# %%
from sklearn.metrics import accuracy_score

y_pred_gbc = gbc.predict(x_test)

print('----'*30)

gbc_accuracy = round(accuracy_score(y_test,y_pred_gbc) *100,2)
print('Accuracy: ',gbc_accuracy,'%')
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Accuracy:  100.0 %

# %%
# sample model scores (replace these with your actual model scores)
model_scores = {
    'Logistic Regression': log_reg_accuracy,
    'Decision Tree Classifier': Dtree_accuracy,
    'Random Forest Classifier': rfc_accuracy,
    'Gradient Boostion Classifier': gbc_accuracy
}

# %%
# sort the model scores in descending order based on their values (higher values first)
sorted_scores = sorted(model_scores.items(),key=lambda x: x[1],reverse=True)

# Display the ranking of the model
print('Model Rankings (Greater values are better):')
for rank, (model_name, score) in enumerate(sorted_scores,start=1):
  print(f'{rank}. {model_name}: {score}')
# Out:
# Model Rankings (Greater values are better):
# 1. Logistic Regression: 100.0
# 2. Decision Tree Classifier: 100.0
# 3. Random Forest Classifier: 100.0
# 4. Gradient Boostion Classifier: 100.0
